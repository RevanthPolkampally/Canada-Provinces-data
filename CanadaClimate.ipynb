# %%
#Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Import dataset
data = pd.read_csv(r'C:\Users\revan\Desktop\Python\Canada Climate\Canadian_climate_history.csv')

# %%
#Check data
data.head()
# Out:
#              LOCAL_DATE  MEAN_TEMPERATURE_CALGARY  \
# 0  01-Jan-1940 00:00:00                     -11.4
# 1  02-Jan-1940 00:00:00                     -12.0
# 2  03-Jan-1940 00:00:00                     -12.0
# 3  04-Jan-1940 00:00:00                     -11.4
# 4  05-Jan-1940 00:00:00                     -13.1
#
#    TOTAL_PRECIPITATION_CALGARY  MEAN_TEMPERATURE_EDMONTON  \
# 0                          0.5                        NaN
# 1                          0.5                        NaN
# 2                          1.0                        NaN
# 3                          0.8                        NaN
# 4                          0.5                        NaN
#
#    TOTAL_PRECIPITATION_EDMONTON  MEAN_TEMPERATURE_HALIFAX  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# ...

# %%
#Data Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29221 entries, 0 to 29220
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LOCAL_DATE                      29221 non-null  object
#  1   MEAN_TEMPERATURE_CALGARY        29032 non-null  float64
#  2   TOTAL_PRECIPITATION_CALGARY     29048 non-null  float64
#  3   MEAN_TEMPERATURE_EDMONTON       21564 non-null  float64
#  4   TOTAL_PRECIPITATION_EDMONTON    21575 non-null  float64
#  5   MEAN_TEMPERATURE_HALIFAX        22057 non-null  float64
#  6   TOTAL_PRECIPITATION_HALIFAX     21995 non-null  float64
#  7   MEAN_TEMPERATURE_MONCTON        26885 non-null  float64
#  8   TOTAL_PRECIPITATION_MONCTON     26454 non-null  float64
#  9   MEAN_TEMPERATURE_MONTREAL       28466 non-null  float64
#  10  TOTAL_PRECIPITATION_MONTREAL    28491 non-null  float64
#  11  MEAN_TEMPERATURE_OTTAWA         29145 non-null  float64
# ...

# %%
#Check null values
data.isnull().sum()
# Out:
# LOCAL_DATE                           0
# MEAN_TEMPERATURE_CALGARY           189
# TOTAL_PRECIPITATION_CALGARY        173
# MEAN_TEMPERATURE_EDMONTON         7657
# TOTAL_PRECIPITATION_EDMONTON      7646
# MEAN_TEMPERATURE_HALIFAX          7164
# TOTAL_PRECIPITATION_HALIFAX       7226
# MEAN_TEMPERATURE_MONCTON          2336
# TOTAL_PRECIPITATION_MONCTON       2767
# MEAN_TEMPERATURE_MONTREAL          755
# TOTAL_PRECIPITATION_MONTREAL       730
# MEAN_TEMPERATURE_OTTAWA             76
# TOTAL_PRECIPITATION_OTTAWA          81
# MEAN_TEMPERATURE_QUEBEC           1214
# TOTAL_PRECIPITATION_QUEBEC        1227
# MEAN_TEMPERATURE_SASKATOON        2473
# TOTAL_PRECIPITATION_SASKATOON     3755
# MEAN_TEMPERATURE_STJOHNS           808
# TOTAL_PRECIPITATION_STJOHNS        822
# MEAN_TEMPERATURE_TORONTO            74
# TOTAL_PRECIPITATION_TORONTO         80
# MEAN_TEMPERATURE_VANCOUVER          53
# TOTAL_PRECIPITATION_VANCOUVER       55
# MEAN_TEMPERATURE_WHITEHORSE       1691
# ...

# %%
#Data Statistics
data.describe()
# Out:
#        MEAN_TEMPERATURE_CALGARY  TOTAL_PRECIPITATION_CALGARY  \
# count              29032.000000                 29048.000000
# mean                   4.038516                     1.180212
# std                   11.006215                     3.846286
# min                  -37.500000                     0.000000
# 25%                   -2.500000                     0.000000
# 50%                    5.300000                     0.000000
# 75%                   12.900000                     0.500000
# max                   26.200000                    92.600000
#
#        MEAN_TEMPERATURE_EDMONTON  TOTAL_PRECIPITATION_EDMONTON  \
# count               21564.000000                  21575.000000
# mean                    2.311584                      1.246239
# std                    12.285520                      3.887939
# min                   -40.800000                      0.000000
# 25%                    -5.800000                      0.000000
# ...

# %%
#Deleting the columns if the columns are empty than 10%
threshold = len(data)*0.1
threshold
# Out:
# 2922.1000000000004

# %%
#Rows and Columns
data.shape
# Out:
# (29221, 27)

# %%
#Droping columns which have more null values like less than 10% 
data.dropna(thresh=threshold,axis=1,inplace=True)

# %%
#Check any columns got dropped
data.shape
# Out:
# (29221, 27)

# %%
#fill null vales with median as these are numerical values
def imp_median(series):
    return series.fillna(series.median())

# %%
#Filling all the columns with median as it would make sense filling with median as they are numerical values
data.MEAN_TEMPERATURE_CALGARY= data["MEAN_TEMPERATURE_CALGARY"].transform(imp_median)
data.TOTAL_PRECIPITATION_CALGARY= data["TOTAL_PRECIPITATION_CALGARY"].transform(imp_median)
data.MEAN_TEMPERATURE_EDMONTON= data["MEAN_TEMPERATURE_EDMONTON"].transform(imp_median)
data.TOTAL_PRECIPITATION_EDMONTON= data["TOTAL_PRECIPITATION_EDMONTON"].transform(imp_median)
data.MEAN_TEMPERATURE_HALIFAX= data["MEAN_TEMPERATURE_HALIFAX"].transform(imp_median)
data.TOTAL_PRECIPITATION_HALIFAX= data["TOTAL_PRECIPITATION_HALIFAX"].transform(imp_median)
data.MEAN_TEMPERATURE_MONCTON= data["MEAN_TEMPERATURE_MONCTON"].transform(imp_median)
data.TOTAL_PRECIPITATION_MONCTON= data["TOTAL_PRECIPITATION_MONCTON"].transform(imp_median)
data.MEAN_TEMPERATURE_MONTREAL= data["MEAN_TEMPERATURE_MONTREAL"].transform(imp_median)
data.TOTAL_PRECIPITATION_MONTREAL= data["TOTAL_PRECIPITATION_MONTREAL"].transform(imp_median)
data.MEAN_TEMPERATURE_OTTAWA= data["MEAN_TEMPERATURE_OTTAWA"].transform(imp_median)
data.TOTAL_PRECIPITATION_OTTAWA= data["TOTAL_PRECIPITATION_OTTAWA"].transform(imp_median)
data.MEAN_TEMPERATURE_QUEBEC= data["MEAN_TEMPERATURE_QUEBEC"].transform(imp_median)
data.TOTAL_PRECIPITATION_QUEBEC= data["TOTAL_PRECIPITATION_QUEBEC"].transform(imp_median)
data.MEAN_TEMPERATURE_SASKATOON= data["MEAN_TEMPERATURE_SASKATOON"].transform(imp_median)
data.TOTAL_PRECIPITATION_SASKATOON= data["TOTAL_PRECIPITATION_SASKATOON"].transform(imp_median)
data.MEAN_TEMPERATURE_STJOHNS= data["MEAN_TEMPERATURE_STJOHNS"].transform(imp_median)
data.TOTAL_PRECIPITATION_STJOHNS= data["TOTAL_PRECIPITATION_STJOHNS"].transform(imp_median)
data.MEAN_TEMPERATURE_TORONTO= data["MEAN_TEMPERATURE_TORONTO"].transform(imp_median)
data.TOTAL_PRECIPITATION_TORONTO= data["TOTAL_PRECIPITATION_TORONTO"].transform(imp_median)
data.MEAN_TEMPERATURE_VANCOUVER= data["MEAN_TEMPERATURE_VANCOUVER"].transform(imp_median)
data.TOTAL_PRECIPITATION_VANCOUVER= data["TOTAL_PRECIPITATION_VANCOUVER"].transform(imp_median)
data.MEAN_TEMPERATURE_WHITEHORSE= data["MEAN_TEMPERATURE_WHITEHORSE"].transform(imp_median)
data.TOTAL_PRECIPITATION_WHITEHORSE= data["TOTAL_PRECIPITATION_WHITEHORSE"].transform(imp_median)
data.MEAN_TEMPERATURE_WINNIPEG= data["MEAN_TEMPERATURE_WINNIPEG"].transform(imp_median)
data.TOTAL_PRECIPITATION_WINNIPEG= data["TOTAL_PRECIPITATION_WINNIPEG"].transform(imp_median)

# %%
#Check any null values again
data.isnull().sum()
# Out:
# LOCAL_DATE                        0
# MEAN_TEMPERATURE_CALGARY          0
# TOTAL_PRECIPITATION_CALGARY       0
# MEAN_TEMPERATURE_EDMONTON         0
# TOTAL_PRECIPITATION_EDMONTON      0
# MEAN_TEMPERATURE_HALIFAX          0
# TOTAL_PRECIPITATION_HALIFAX       0
# MEAN_TEMPERATURE_MONCTON          0
# TOTAL_PRECIPITATION_MONCTON       0
# MEAN_TEMPERATURE_MONTREAL         0
# TOTAL_PRECIPITATION_MONTREAL      0
# MEAN_TEMPERATURE_OTTAWA           0
# TOTAL_PRECIPITATION_OTTAWA        0
# MEAN_TEMPERATURE_QUEBEC           0
# TOTAL_PRECIPITATION_QUEBEC        0
# MEAN_TEMPERATURE_SASKATOON        0
# TOTAL_PRECIPITATION_SASKATOON     0
# MEAN_TEMPERATURE_STJOHNS          0
# TOTAL_PRECIPITATION_STJOHNS       0
# MEAN_TEMPERATURE_TORONTO          0
# TOTAL_PRECIPITATION_TORONTO       0
# MEAN_TEMPERATURE_VANCOUVER        0
# TOTAL_PRECIPITATION_VANCOUVER     0
# MEAN_TEMPERATURE_WHITEHORSE       0
# TOTAL_PRECIPITATION_WHITEHORSE    0
# MEAN_TEMPERATURE_WINNIPEG         0
# ...

# %%
#data statistics changed 
data.describe()
# Out:
#        MEAN_TEMPERATURE_CALGARY  TOTAL_PRECIPITATION_CALGARY  \
# count              29221.000000                 29221.000000
# mean                   4.046675                     1.173225
# std                   10.971028                     3.835952
# min                  -37.500000                     0.000000
# 25%                   -2.500000                     0.000000
# 50%                    5.300000                     0.000000
# 75%                   12.800000                     0.500000
# max                   26.200000                    92.600000
#
#        MEAN_TEMPERATURE_EDMONTON  TOTAL_PRECIPITATION_EDMONTON  \
# count               29221.000000                  29221.000000
# mean                    2.806420                      0.920146
# std                    10.586401                      3.385367
# min                   -40.800000                      0.000000
# 25%                    -2.000000                      0.000000
# ...

# %%
#Deleting ' 00:00:00' from date time column
data['LOCAL_DATE'] = data['LOCAL_DATE'].apply(lambda x : str(x).replace(' 00:00:00','')if ' 00:00:00' in str(x) else str(x))

# %%
#Seperating year from date
from datetime import datetime
data['LOCAL_DATE']=pd.to_datetime(data.LOCAL_DATE, errors='coerce').dt.year

# %%
#Check data
data.head()
# Out:
#    LOCAL_DATE  MEAN_TEMPERATURE_CALGARY  TOTAL_PRECIPITATION_CALGARY  \
# 0        1940                     -11.4                          0.5
# 1        1940                     -12.0                          0.5
# 2        1940                     -12.0                          1.0
# 3        1940                     -11.4                          0.8
# 4        1940                     -13.1                          0.5
#
#    MEAN_TEMPERATURE_EDMONTON  TOTAL_PRECIPITATION_EDMONTON  \
# 0                        4.2                           0.0
# 1                        4.2                           0.0
# 2                        4.2                           0.0
# 3                        4.2                           0.0
# 4                        4.2                           0.0
#
#    MEAN_TEMPERATURE_HALIFAX  TOTAL_PRECIPITATION_HALIFAX  \
# 0                       7.0                          0.0
# 1                       7.0                          0.0
# ...

# %%
#Grouping by year
grp = data.groupby('LOCAL_DATE')
x = grp['MEAN_TEMPERATURE_CALGARY'].agg(np.mean)
y = grp['TOTAL_PRECIPITATION_CALGARY'].agg(np.mean)

# %%
#Visualisation of calgarys mean temperature
plt.figure(figsize=(20,7))
plt.plot(x)

# %%
#Ploting in dash
import dash
import dash_core_components as dcc
import plotly.graph_objs as go
import dash_html_components as html

# %%
app=dash.Dash()

# %%
app.layout=html.Div([
        dcc.Graph(
            id='scatter_chart',
            figure = {
                'data' : [
                    go.Scatter(
                        x=data.LOCAL_DATE,
                        y= data.MEAN_TEMPERATURE_CALGARY,
                        mode = 'markers'
                    )
                ]
            }
        )
])

# %%
if __name__=='__main__':
    app.run_server(port=4051)
# Out:
# Dash is running on http://127.0.0.1:4051/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4051/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Nov/2020 20:49:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 20:49:50] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_8_3m1605490778.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 20:49:50] "GET /_dash-component-suites/dash_renderer/react@16.v1_8_3m1605490778.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 20:49:50] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_8_3m1605490778.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 20:49:50] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_8_3m1605490778.7.2.min.js HTTP/1.1" 200 -
# ...
